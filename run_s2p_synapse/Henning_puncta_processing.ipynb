# %%
import os
from shutil import copyfile

# %%
def export_image_files_to_suite2p_format(tiff_path):
    os.chdir(tiff_path)
    destination = tiff_path
    for file in os.listdir(tiff_path):
        if file.endswith(".tif"):

            name = file[0:-4]
            os.makedirs(name, exist_ok = True)
            destination = tiff_path + '/' + name + '/' + file
            copyfile(file, destination)
            os.remove(file)

# %%
export_image_files_to_suite2p_format(r'C:\Users\jcbeg\Imaging\Camin_Ca2+\suite2p\process1')

# %%
tiff_path = r'D:\calcium imaging\CellProfiler_SynapseCount\DIV16_cs3_CNQX_over_baseline'
os.chdir(tiff_path)
for file in os.listdir(tiff_path):
    #if file.endswith(".tif"):

    name = file[0:-4]
    os.makedirs(name, exist_ok = True)
    destination = tiff_path + '/' + name + '/' + file
    copyfile(file, destination)
    del file

# %%
suite2p_path = r'D:\calcium imaging\suite2p_vids'
for files in suite2p_path:
    print(os.walk(files))

# %%
suite2p_path = r'D:\calcium imaging\suite2p_vids'
suite2p_path = os.pardir

# %%
from spont_syn_suite2p_utility import *
from spont_syn_detector_utility import *
from spont_syn_analysis_utility import *
from spont_syn_plotting_utility import *

# %%
load_suite2p_output?

# %%
get_all_suite2p_outputs_in_path(r"C:\Users\jcbeg\Imaging\Camin_Ca2+\ImageJ_New", check_for_iscell = False)
# Out:
# ['C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs1 mg1',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs1 mg2',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs1 mg3',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs1 mg4',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs3 mg1',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs3 mg2',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs3 mg3',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 KO cs3 mg4',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 OE cs1 mg1',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 OE cs1 mg2',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 OE cs1 mg3',
#  'C:\\Users\\jcbeg\\Imaging\\Camin_Ca2+\\ImageJ_New\\20201205 OE cs1 mg4',
# ...

# %%
translate_suite2p_outputs_to_csv(r"C:\Users\jcbeg\Imaging\Camin_Ca2+\ImageJ_New", r"C:\Users\jcbeg\Imaging\Camin_Ca2+\ImageJ_New_csv")

# %%
process_spike_csvs_to_pkl(r"C:\Users\jcbeg\Imaging\Camin_Ca2+\ImageJ_New_csv",r"C:\Users\jcbeg\Imaging\Camin_Ca2+\ImageJ_New_pickle")

# %%
henning_experiment_structure = {
    "control": {
        "DIV16_cs2_r1": [f"DIV16_cs2_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV16_cs3_r1":[f"DIV16_cs3_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_r1": [f"DIV17_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs6_r1":[f"DIV17_cs6_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs4_r1":[f"DIV17_cs4_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs3_r2":[f"DIV17_cs3_r2_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r1":[f"DIV18_cs2_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
#         "DIV18_cs2_r2":[f"DIV18_cs2_r2_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r3":[f"DIV18_cs2_r3_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r1":[f"DIV18_cs3_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
#         "DIV18_cs3_r2":[f"DIV18_cs3_r2_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r3":[f"DIV18_cs3_r3_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs4_r1":[f"DIV18_cs4_r1_baselineDur420sInt550msBin550ms_filtered.pkl"],
#         "DIV18_cs4_r2":[f"DIV18_cs4_r2_baselineDur420sInt550msBin550ms_filtered.pkl"]
    },
    
    "overexpression": { 
        "DIV17_r1": [f"DIV17_r1_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs6_r1":[f"DIV17_cs6_r1_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs4_r1":[f"DIV17_cs4_r1_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r1":[f"DIV18_cs2_r1_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r3":[f"DIV18_cs2_r3_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r1":[f"DIV18_cs3_r1_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r3":[f"DIV18_cs3_r3_PDBuDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs4_r1":[f"DIV18_cs4_r1_PDBuDur420sInt550msBin550ms_filtered.pkl"],
          
    },
    "knockout": {
        "DIV16_cs2_r1": [f"DIV16_cs2_r1_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs4_r1":[f"DIV17_cs4_r1_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs3_r2":[f"DIV17_cs3_r2_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r2":[f"DIV18_cs2_r2_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r3":[f"DIV18_cs2_r3_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r2":[f"DIV18_cs3_r2_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r3":[f"DIV18_cs3_r3_APVDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs4_r2":[f"DIV18_cs4_r2_APVDur420sInt550msBin550ms_filtered.pkl"]
    },
    "CNQX": {
        "DIV16_cs3_r1":[f"DIV16_cs3_r1_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs3_r2":[f"DIV17_cs3_r2_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV17_cs6_r1":[f"DIV17_cs6_r1_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r1":[f"DIV18_cs2_r1_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r1":[f"DIV18_cs3_r1_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs4_r1":[f"DIV18_cs4_r1_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs2_r2":[f"DIV18_cs2_r2_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r2":[f"DIV18_cs3_r2_CNQXDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs4_r2":[f"DIV18_cs4_r2_CNQXDur420sInt550msBin550ms_filtered.pkl"]
    },
    "Potentiated":{
        "DIV18_cs2_r2":[f"DIV18_cs2_r2_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs3_r2":[f"DIV18_cs3_r2_baselineDur420sInt550msBin550ms_filtered.pkl"],
        "DIV18_cs4_r2":[f"DIV18_cs4_r2_baselineDur420sInt550msBin550ms_filtered.pkl"]
        
    }
        
}

# %% [markdown]
# combined = pd.read_csv("combined.csv");
#
# sns.set(style="whitegrid");
#
# ReplicateAverages = combined.groupby(['Treatment','Replicate'], as_index=False).agg({'Speed': "mean"});
#
# ReplicateAvePivot = ReplicateAverages.pivot_table(columns='Treatment', values='Speed', index="Replicate"); statistic, pvalue = scipy.stats.ttest_rel(ReplicateAvePivot['Control'], ReplicateAvePivot['Drug']);
#
# P_value = str(float(round(pvalue, 3))); sns.swarmplot(x="Treatment", y="Speed", hue="Replicate", data=combined); ax = sns.swarmplot(x="Treatment", y="Speed", hue="Replicate", size=15, edgecolor="k", linewidth=2, data=ReplicateAverages); ax.legend_.remove(); x1, x2 = 0, 1; y, h, col = combined['Speed'].max() + 2, 2, 'k'; plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col); plt.text((x1+x2)*.5, y+h*2, "P = "+P_value, ha='center', va='bottom', color=col).

# %%
"""the function below will make a JCB(HAH) Superplot of the synapses in 
each condition and the distribution of each at different levels / treatment paradigms"""

# %%
sns.set(style="whitegrid")
#We could group once we split the video up by group (ctrl/APV/PDBu/CNQX) or dataset (DIV/coverslip) --> update exp structure
ReplicateAverages = combined.groupby(['IsUsed', 'NeuronId'], as_index=False).agg({'SpikesCount': "mean"})

#pivot_table columns = group (most likely/ cs) values = amplitude / spike freq/ diff avg index = replicate (cs)
ReplicateAvePivot = ReplicateAverages.pivot_table(columns = 'NeuronId', values = 'SpikesCount', index='IsUsed')

#statistics / pvalue will be done on the subgroups within the columns / group) (ctrl/APV/PDBu/CNQX)
statistic, pvalue = scipystats.ttest_rel(ReplicateAvePivot['ctrl'],ReplicateAvePivot['PDBu'],
                                         ReplicateAvePivot['APV'],ReplicateAvePivot['CNQX'])


#I assume this is where we make the actual plot
P_value = str(float(round(pvalue,3)))
sns.swarmplot(x="group", y="Amplitude", hue = "dataset", data = combined)
ax = sns.swarmplot(x="group", y=VALUE, hue = 'dataset', size = 15, edgecolor = "k", linewidth = 2, data = ReplicateAverages)
ax.legend_remove()
x1,x2=0,1
y,h,col = combined['VALUE'].max() +2, 2, 'k'
plt.plot([x1,x1,x2,x2],[y,y+h,y+h,y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h*2, "P="+P_value, ha='center', va='bottom', color=col)

# %%
test = pd.read_pickle(r"D:\calcium imaging\220930_C_DIV17_GCaMP6f\cs3PDBu_above_baseline\DIV17_cs3_baseline2PDBu2CNQX\DIV17_cs3_baseline2PDBu2CNQXDur420sInt550msBin550ms_filtered.pkl")
combined = test["cell_stats"]
combined
# Out:
#      NeuronId  IsUsed      Skew  \
# 0           0    True  3.910535
# 2           2    True  3.699969
# 3           3    True  5.511206
# 6           6    True  3.927642
# 7           7    True  7.152518
# ..        ...     ...       ...
# 612       612    True  4.467327
# 637       637    True  3.571266
# 678       678    True  7.785272
# 758       758    True  6.487752
# 776       776    True  3.112611
#
#                                            SpikesTimes  \
# 0    [31.900000000000002, 56.650000000000006, 62.15...
# 2    [18.700000000000003, 52.800000000000004, 74.80...
# 3    [1.1, 15.950000000000001, 17.05, 39.0500000000...
# 6    [3.8500000000000005, 16.5, 25.3, 26.9500000000...
# 7    [4.4, 74.80000000000001, 90.2, 96.800000000000...
# ..                                                 ...
# 612  [158.4, 170.5, 172.15, 176.55, 179.3, 183.15, ...
# 637  [174.35000000000002, 243.10000000000002, 267.8...
# 678  [74.80000000000001, 134.20000000000002, 168.85...
# ...

# %%
experiment_structure = {
    "control": {
        "ctrl01": [f"DIV16_cs2_r1_baselineDur420sInt550msBin550ms_filtered.pkl", 
                f"DIV16_cs3_r1_baselineDur420sInt550msBin550ms_filtered.pkl",
                #f"DIV17_r1_baselineDur420sInt550msBin550ms_filtered.pkl",
                f"DIV17_cs6_r1_baselineDur420sInt550msBin550ms_filtered.pkl",
                f"DIV17_cs4_r1_baselineDur420sInt550msBin550ms_filtered.pkl",
                f"DIV17_cs3_r2_baselineDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs2_r1_baselineDur420sInt550msBin550ms_filtered.pkl",
                  #f"DIV18_cs2_r2_baselineDur420sInt550msBin550ms_filtered.pkl",
                  #f"DIV18_cs2_r3_baselineDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs3_r1_baselineDur420sInt550msBin550ms_filtered.pkl",
                  #f"DIV18_cs3_r2_baselineDur420sInt550msBin550ms_filtered.pkl",
                  #f"DIV18_cs3_r3_baselineDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs4_r1_baselineDur420sInt550msBin550ms_filtered.pkl"] 
                  #f"DIV18_cs4_r3_baselineDur420sInt550msBin550ms_filtered.pkl"]
    },
    
    "PDBu": { 
        "PDBu_treatment": [f"DIV17_r1_PDBuDur420sInt550msBin550ms_filtered.pkl",
                f"DIV17_cs6_r1_PDBuDur420sInt550msBin550ms_filtered.pkl",
                f"DIV17_cs4_r1_PDBuDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs2_r1_PDBuDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs2_r3_PDBuDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs3_r1_PDBuDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs3_r3_PDBuDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs4_r1_PDBuDur420sInt550msBin550ms_filtered.pkl",
                  f"DIV18_cs4_r3_PDBuDur420sInt550msBin550ms_filtered.pkl"]
    },
    "APV": {
        "APV_treatment": [f"DIV16_cs2_r1_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV17_cs4_r1_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV17_cs3_r2_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV18_cs2_r2_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV18_cs2_r3_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV18_cs3_r2_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV18_cs3_r3_APVDur420sInt550msBin550ms_filtered.pkl",
                          f"DIV18_cs4_r3_APVDur420sInt550msBin550ms_filtered.pkl"]
    }
        
}

# %%
experiment_structure = {
    "control": {
        "baseline": [f"DIV1{i}_cs{j}_r{k}_baseline*.pkl" for i,k,j in [1:9]]
    },
    "APV": {
        "dataset2": [f"DIV1{i}_cs{j}_r{k}_APV*.pkl" for i,k,j in range(1,9)]
    },
    "PDBu": {
        "dataset3": [f"DIV1{i}_cs{j}_r{k}_PDBu*.pkl" for i,k,j in range(1,9)]
    },
    "CNQX": {
        "dataset4": [f"DIV1{i}_cs{j}_r{k}_CNQX*.pkl" for i,k,j in range(1,9)]
    },
}

# %%
experiment_cell_stats, experiment_binned_stats = build_experiment_dfs(r"C:\Users\jcbeg\Code\JupyterNotebooks\Calcium_Imaging\spont_syn_process\process_3_manual", experiment_structure)

# %%
experiment_binned_stats
# Out:
#                                    Bin_Limits  Spikes  Frequency    group  \
# 0                                 (0.0, 0.55)       0   0.000000  control
# 1                                 (0.55, 1.1)       7  12.727273  control
# 2                   (1.1, 1.6500000000000001)      10  18.181818  control
# 3                   (1.6500000000000001, 2.2)       3   5.454545  control
# 4                                 (2.2, 2.75)       8  14.545455  control
# ..                                        ...     ...        ...      ...
# 759  (417.45000000000005, 418.00000000000006)       0   0.000000      APV
# 760              (418.00000000000006, 418.55)       0   0.000000      APV
# 761                           (418.55, 419.1)       0   0.000000      APV
# 762               (419.1, 419.65000000000003)       0   0.000000      APV
# 763  (419.65000000000003, 420.20000000000005)       0   0.000000      APV
#
#            dataset                                          file_name
# ...

# %%
fig = aggregated_feature_plot(experiment_cell_stats, feature="SpikesFreq", agg_function="mean", comparison_function="mean",
                             significance_check=[["control", "APV"]])
